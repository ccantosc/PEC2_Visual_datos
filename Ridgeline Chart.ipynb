# %% [markdown]
# Visualización de datos. PEC 2. Ridgeline Chart (3).

# %% [markdown]
# Claudia Cantos Codina.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install joypy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from joypy import joyplot

# %%
datos = pd.read_excel("datos_vis.xlsx")

# %%
plt.figure(figsize=(10, 8))
joyplot(datos, by="Comunidades y Ciudades Autonomas", column="Total", colormap=plt.cm.viridis)

plt.title("Ridgeline Chart")
plt.xlabel("INC")

plt.show()
